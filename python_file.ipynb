# %%
# CAPSTONE PROJECT

# %%
# A.PHASE 1 - DATA INGESTION AND CLEANING

# %%
import pandas as pd

# %%
# 1. LOAD CSV FILE

# %%
df = pd.read_csv("raw_sales_data.csv")

# %%
# 2. INSPECT DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10500 entries, 0 to 10499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       10500 non-null  int64
#  1   order_date     10500 non-null  object
#  2   customer_id    10500 non-null  object
#  3   customer_name  9648 non-null   object
#  4   product        10500 non-null  object
#  5   category       10500 non-null  object
#  6   quantity       10500 non-null  int64
#  7   unit_price     10500 non-null  int64
#  8   country        10500 non-null  object
#  9   created_at     10500 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 820.4+ KB

# %%
df.head(5)
# Out:
#    order_id  order_date customer_id    customer_name          product  \
# 0      1000  2024-02-10        C126     Arthur Bowen           Laptop
# 1      1001  07/02/2024        C112      Jason Smith           Laptop
# 2      1002  15/01/2024        C446              NaN   Vacuum Cleaner
# 3      1003  2024-01-10        C048  Jennifer Romero  Air Conditioner
# 4      1004  16/02/2024        C473       Amy Phelps        Microwave
#
#           category  quantity  unit_price country           created_at
# 0      Electronics         5         850     UK   2025-11-01 22:24:47
# 1      Electronics         5         850  France  2025-12-07 08:03:32
# 2  Home Appliances         3         250   China  2025-11-18 22:42:05
# 3  Home Appliances         3        1500     USA  2025-12-01 21:28:40
# 4  Home Appliances         5         300     UAE  2025-11-15 19:15:55

# %%
df.tail(5)
# Out:
#        order_id  order_date customer_id  customer_name   product  \
# 10495      6170  20/02/2024        C292  Diana Mendoza    Laptop
# 10496      8205  2024-01-22        C105     Laura King   Toaster
# 10497      3522  04/01/2024        C457  Henry Shannon   Laptop
# 10498      3215  2024-01-30        C284   Hannah Jones   Camera
# 10499      7968  19/01/2024        C060  Tina Thompson    Laptop
#
#               category  quantity  unit_price  country           created_at
# 10495      electronics         4         850    China  2025-11-04 05:02:01
# 10496  home appliances         2          40    India  2025-11-09 11:11:23
# 10497      Electronics         3         850      UK   2025-12-19 01:38:04
# 10498      Electronics         2         650    China  2025-12-18 22:59:27
# 10499      Electronics         5         850  Nigeria  2025-12-09 13:54:17

# %%
# 3. IDENTIFY AND REMOVE DUPLICATES

# %%
df["order_id"].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10495     True
# 10496     True
# 10497     True
# 10498     True
# 10499     True
# Name: order_id, Length: 10500, dtype: bool

# %%
df = df.drop_duplicates(subset=["order_id"], keep="first")

# %%
#. STANDARDIZE TEXT COLUMNS

# %%
# Select all text (object) columns
text_cols = df.select_dtypes(include="object").columns
# Trim leading & trailing spaces
df[text_cols] = df[text_cols].apply(lambda col: col.str.strip())

# %%
# Apply consistent casing
df["customer_name"] = df["customer_name"].str.title()
df["category"] = df["category"].str.title()
df["country"] = df["country"].str.upper()

# %%
# 5. CONVERT ALL DATES TO STANDARD YYYY-MM-DD FORMAT

# %%
date_cols = ["order_date", "created_at"]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors="coerce")
    df[col] = df[col].dt.strftime("%Y-%m-%d")

# %%
# 6. HANDLE MISSING VALUES

# %%
#Count of missing values
df.isna().sum()
# Out:
# order_id            0
# order_date       4890
# customer_id         0
# customer_name     795
# product             0
# category            0
# quantity            0
# unit_price          0
# country             0
# created_at          0
# dtype: int64

# %%
#filling missing order_date with created_at
df["order_date"] = df["order_date"].fillna(df["created_at"])

#filling customer_name with default
df["customer_name"] = df["customer_name"].fillna("Unknown")

# %%
# Verify that all missing values handled
df.isna().sum()
# Out:
# order_id         0
# order_date       0
# customer_id      0
# customer_name    0
# product          0
# category         0
# quantity         0
# unit_price       0
# country          0
# created_at       0
# dtype: int64

# %%
# VERIFY DATA CLEANING

# %%
df.head(5)
# Out:
#    order_id  order_date customer_id    customer_name          product  \
# 0      1000  2024-02-10        C126     Arthur Bowen           Laptop
# 1      1001  2025-12-07        C112      Jason Smith           Laptop
# 2      1002  2025-11-18        C446          Unknown   Vacuum Cleaner
# 3      1003  2024-01-10        C048  Jennifer Romero  Air Conditioner
# 4      1004  2025-11-15        C473       Amy Phelps        Microwave
#
#           category  quantity  unit_price country  created_at
# 0      Electronics         5         850      UK  2025-11-01
# 1      Electronics         5         850  FRANCE  2025-12-07
# 2  Home Appliances         3         250   CHINA  2025-11-18
# 3  Home Appliances         3        1500     USA  2025-12-01
# 4  Home Appliances         5         300     UAE  2025-11-15

# %%
df.tail(5)
# Out:
#       order_id  order_date customer_id   customer_name     product  \
# 9995     10995  2025-11-14        C394    Heather Cook     Toaster
# 9996     10996  2024-02-02        C227   Rita Hayes Md  Smartwatch
# 9997     10997  2024-02-06        C365  Alexander Hill  Smartphone
# 9998     10998  2024-01-31        C345         Unknown  Smartphone
# 9999     10999  2024-01-09        C365  Patricia Jones  Smartwatch
#
#              category  quantity  unit_price      country  created_at
# 9995  Home Appliances         1          40  SOUTH KOREA  2025-11-14
# 9996      Electronics         5         200  SOUTH KOREA  2025-11-18
# 9997      Electronics         5         500       MEXICO  2025-12-20
# 9998      Electronics         1         500          UAE  2025-11-23
# 9999      Electronics         5         200           UK  2025-12-05

# %%
# 7. SAVE CLEAN DATA

# %%
# Save cleaned data
df.to_csv("clean_sales_data.csv", index=False)

print("Cleaned data saved successfully!")
# Out:
# Cleaned data saved successfully!

# %%
# B. PHASE 2 - LOAD DATA INTO DATABASE

# %%
# 8. CREATED DATABASE USING PostgreSQL named "sales_db"

# %%
# 9. LOAD CLEANED CSV INTO DATABASE

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:%40Dsa2024@localhost:5432/sales_db"
)

# %%
#check connection
with engine.connect() as conn:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
#load clean data into database
df.to_sql(
    "sales_db",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 807

# %%
# 10. RECORDS INSERTED
